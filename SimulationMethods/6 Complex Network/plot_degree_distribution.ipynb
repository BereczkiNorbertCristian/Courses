# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

# %%
N = 100

# %%
f = open("degree_erdos.txt","r")
degree = [0] * N
for i in range(N):
    degree[i] = int(f.readline())

# %%
degree[:10]
# Out:
# [9, 4, 7, 6, 2, 6, 6, 5, 7, 5]

# %%
ser = pd.Series(data=degree)

# %%
fig, ax = plt.subplots(1, 1, figsize=(10,6))
sns.distplot(ser,ax=ax)

# %%
f = open("degree_preference.txt","r")
degree = [0] * N
for i in range(N):
    degree[i] = int(f.readline())

# %%
degree[:10]
# Out:
# [10, 10, 17, 13, 10, 6, 2, 4, 4, 1]

# %%
ser = pd.Series(data=degree)

# %%
fig, ax = plt.subplots(1, 1, figsize=(10,6))
sns.distplot(ser,kde=False,ax=ax)
